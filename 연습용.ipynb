# %% [markdown]
# # 자료형_숫자형

# %% [markdown]
# ## 1. 숫자형은 어떻게 만들고 사용할까?

# %%
a = 123
a
# Out:
# 123

# %%
a = -178
a
# Out:
# -178

# %%
a = 0
a
# Out:
# 0

# %%
a = 1.2
a
# Out:
# 1.2

# %%
a = -3.45
a
# Out:
# -3.45

# %%
a = 4.24e10
a
# Out:
# 42400000000.0

# %%
a = 4.24e-10
a
# Out:
# 4.24e-10

# %%
a = 0o177
print(a)
# Out:
# 127

# %%
a = 0x8ff
b= 0xABC
print(b)
# Out:
# 2748

# %%
print(a)
# Out:
# 2303

# %% [markdown]
# ## 2.숫자형을 활용하기 위한 연산자

# %%
a= 3
b= 4
a+b
# Out:
# 7
