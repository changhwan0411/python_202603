# %%
"Hello bro"
# Out:
# 'Hello bro'

# %%
'You know Python is really fun'
# Out:
# 'You know Python is really fun'

# %%
"""Life is too very short.You need to learn python"""
# Out:
# 'Life is too very short.You need to learn python'

# %%
'''Life is too short.You need to learn python'''
# Out:
# 'Life is too short.You need to learn python'

# %%
food = "Python's favortie food is chicken"
food
