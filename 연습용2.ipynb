# %% [markdown]
# # 3-4_자료형/튜플

# %% [markdown]
# ## 1.튜플은 어떻게 만들까?

# %%
t1 = ()

# %%
type(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 type(t1)
#
# TypeError: 'tuple' object is not callable
